# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams.update({'font.size':14})
plt.rcParams.update({'font.family': 'Times new roman'})

# %%
column_names = ['Time', 'Ipv', 'Vpv', 'Vdc', 'ia', 'ib', 'ic', 'va', 'vb', 'vc', 'Iabc',
       'If', 'Vabc', 'Vf', 'label']
solar_data_Lim_power = pd.DataFrame(columns=column_names)
solar_data_Max_power = pd.DataFrame(columns=column_names)

# %%
for num in range(0,8):
  df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Github/PanelFaultDiagnosis/CSV_Files/F{}L.csv'.format(num))
  df['label'] = np.full((len(df),1),'F{}L'.format(num))
  solar_data_Lim_power = pd.concat([solar_data_Lim_power, df], ignore_index=True)

  df1 = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Github/PanelFaultDiagnosis/CSV_Files/F{}M.csv'.format(num))
  df1['label'] = np.full((len(df1),1),'F{}M'.format(num))
  solar_data_Max_power = pd.concat([solar_data_Max_power, df1], ignore_index=True)

# %%
solar_data_Lim_power
# Out:
#               Time       Ipv         Vpv         Vdc        ia        ib  \
# 0         0.000028  1.572327  101.348877  144.140625 -0.135133  0.490112
# 1         0.000128  1.503265  101.458740  143.554688 -0.108277  0.510254
# 2         0.000228  1.492859  101.574707  143.554688 -0.168702  0.496826
# 3         0.000328  1.558136  101.312256  143.261719 -0.135133  0.510254
# 4         0.000428  1.631927  101.141357  143.847656 -0.202271  0.503540
# ...            ...       ...         ...         ...       ...       ...
# 1093407  14.399588  1.440826  101.574707  142.675781  0.469115 -0.537109
# 1093408  14.399688  1.496643  101.916504  142.675781  0.422118 -0.463257
# 1093409  14.399788  1.484344  102.484131  142.968750  0.475829 -0.523682
# 1093410  14.399888  1.507996  101.788330  142.968750  0.448974 -0.429688
# 1093411  14.399988  1.492859  101.751709  142.968750  0.489257 -0.490112
#
#                ic          va          vb          vc      Iabc         If  \
# ...

# %%
solar_data_Max_power
# Out:
#               Time       Ipv        Vpv         Vdc        ia        ib  \
# 0         0.000041  2.369843  90.429688  147.949219  0.616820 -0.530396
# 1         0.000141  2.449310  90.161133  148.535156  0.603393 -0.543823
# 2         0.000241  2.345245  90.740967  147.656250  0.630248 -0.503540
# 3         0.000341  2.176849  91.003418  147.656250  0.636962 -0.496826
# 4         0.000441  2.226044  91.113281  147.363281  0.643676 -0.483398
# ...            ...       ...        ...         ...       ...       ...
# 1070063  14.399531  2.460663  86.895752  144.726562  0.012572  0.584106
# 1070064  14.399631  2.362274  86.975098  144.726562  0.019286  0.550537
# 1070065  14.399731  2.302673  86.694336  144.726562 -0.034425  0.610962
# 1070066  14.399831  2.293213  87.225342  144.726562 -0.034425  0.584106
# 1070067  14.399931  2.304565  87.414551  144.433594 -0.067994  0.631104
#
#                ic          va          vb          vc      Iabc         If  \
# ...

# %%
solar_data_Lim_power1 = solar_data_Max_power.iloc[::1000,:]
for col in solar_data_Lim_power1.columns[1:-1]:
  fig = plt.figure(figsize=(5,5))
  sns.scatterplot(data=solar_data_Lim_power1, x='Time', y=col, hue='label',style="label",ec=None,palette='rocket',edgecolor="white",s=100)
  plt.xlabel('Time')
  plt.ylabel(col)
  plt.show()

# %%
# %mkdir /content/drive/MyDrive/'Colab Notebooks'/Github/PanelFaultDiagnosis/'PreProcessed Data'/

# %%
solar_data_Lim_power.iloc[::100,:].to_csv(r'/content/drive/MyDrive/Colab Notebooks/Github/PanelFaultDiagnosis/PreProcessed Data/Lim_solar_data.csv',index=False)
solar_data_Max_power.iloc[::100,:].to_csv(r'/content/drive/MyDrive/Colab Notebooks/Github/PanelFaultDiagnosis/PreProcessed Data/Max_solar_data.csv',index=False)

# %%
# Out:
# /content
